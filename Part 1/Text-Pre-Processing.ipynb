# %% [markdown]
# # Natural Language Processing
#
# ## Basic Text Pre-processing
#
# #### Notebook By: PALLAVI BHIMTE
#
#
# Version: 1.0
#
# Environment: Python 3 and Google Colab Jupyter notebook
#
# Libraries used:
# * pandas
# * re
# * numpy
# * nltk
# * pickle
# * os
# * sklearn
# * itertools
#
#
# ## Data Description:
# A large collection of job advertisements documents is provided with near about 50,000 document. There are 8 subfolders inside the data folder and each of those folder is a job category. Each document belongs to one of the job categories from: IT, Accounting_Finance, Engineering, Healthcare Nursing, Hospitality Catering,  PR Advertising Marketing, or Sales and Teaching.
#
# ## Introduction
# In Task 1, all the basic pre-processing steps are performed to make the description of each job advertisement clean and ready for further analysis. This notebook covers extraction of each job advertisement and steps to clean the description by:
#
# * tokenising the word with the help of this regular expression r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?"
# * converting each word to lower case
# * removing words with less than 2
# * Removing stopwords using the provided stop words list
# * Removing the word that appears only once in the document collection, based on term frequency
# * Removing the top 50 most frequent words based on document frequency
# * Extracting the top 10 Bigrams based on term frequency
#
# The three output files:
# 1. vocab.txt saves the unigram vocabulary
# 2. bigram.txt saves the found bigrams found in the whole document collection as well as their term frequency
# 3. job_ads.txt saves information and the pre-processed description text for all the job advertisement documents with respective ID, category, webindex, title, and description.

# %% [markdown]
# ## Importing libraries

# %%
# Load the Drive helper and mount
from google.colab import drive

# This will prompt for authorization.
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip "/content/drive/My Drive/data.zip"

# %%
# !unzip "/content/drive/My Drive/data.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/Engineering/Job_18156.txt
#   inflating: __MACOSX/data/Engineering/._Job_18156.txt
#   inflating: data/Engineering/Job_19248.txt
#   inflating: __MACOSX/data/Engineering/._Job_19248.txt
#   inflating: data/Engineering/Job_21258.txt
#   inflating: __MACOSX/data/Engineering/._Job_21258.txt
#   inflating: data/Engineering/Job_17932.txt
#   inflating: __MACOSX/data/Engineering/._Job_17932.txt
#   inflating: data/Engineering/Job_20146.txt
#   inflating: __MACOSX/data/Engineering/._Job_20146.txt
#   inflating: data/Engineering/Job_22037.txt
#   inflating: __MACOSX/data/Engineering/._Job_22037.txt
#   inflating: data/Engineering/Job_15843.txt
#   inflating: __MACOSX/data/Engineering/._Job_15843.txt
#   inflating: data/Engineering/Job_14585.txt
#   inflating: __MACOSX/data/Engineering/._Job_14585.txt
#   inflating: data/Engineering/Job_20620.txt
#   inflating: __MACOSX/data/Engineering/._Job_20620.txt
#   inflating: data/Engineering/Job_16392.txt
#   inflating: __MACOSX/data/Engineering/._Job_16392.txt
#   inflating: data/Engineering/Job_20634.txt
#   inflating: __MACOSX/data/Engineering/._Job_20634.txt
#   inflating: data/Engineering/Job_17098.txt
#   inflating: __MACOSX/data/Engineering/._Job_17098.txt
#   inflating: data/Engineering/Job_16386.txt
#   inflating: __MACOSX/data/Engineering/._Job_16386.txt
#   inflating: data/Engineering/Job_22023.txt
#   inflating: __MACOSX/data/Engineering/._Job_22023.txt
#   inflating: data/Engineering/Job_15857.txt
#   inflating: __MACOSX/data/Engineering/._Job_15857.txt
#   inflating: data/Engineering/Job_14591.txt
#   inflating: __MACOSX/data/Engineering/._Job_14591.txt
#   inflating: data/Engineering/Job_17715.txt
#   inflating: __MACOSX/data/Engineering/._Job_17715.txt
#   inflating: data/Engineering/Job_19738.txt
#   inflating: __MACOSX/data/Engineering/._Job_19738.txt
#   inflating: data/Engineering/Job_15102.txt
#   inflating: __MACOSX/data/Engineering/._Job_15102.txt
#   inflating: data/Engineering/Job_15664.txt
#   inflating: __MACOSX/data/Engineering/._Job_15664.txt
#   inflating: data/Engineering/Job_20807.txt
#   inflating: __MACOSX/data/Engineering/._Job_20807.txt
#   inflating: data/Engineering/Job_18340.txt
#   inflating: __MACOSX/data/Engineering/._Job_18340.txt
#   inflating: data/Engineering/Job_17073.txt
#   inflating: __MACOSX/data/Engineering/._Job_17073.txt
#   inflating: data/Engineering/Job_20813.txt
#   inflating: __MACOSX/data/Engineering/._Job_20813.txt
#   inflating: data/Engineering/Job_16379.txt
#   inflating: __MACOSX/data/Engineering/._Job_16379.txt
#   inflating: data/Engineering/Job_18354.txt
#   inflating: __MACOSX/data/Engineering/._Job_18354.txt
#   inflating: data/Engineering/Job_17067.txt
#   inflating: __MACOSX/data/Engineering/._Job_17067.txt
#   inflating: data/Engineering/Job_15670.txt
#   inflating: __MACOSX/data/Engineering/._Job_15670.txt
#   inflating: data/Engineering/Job_15116.txt
#   inflating: __MACOSX/data/Engineering/._Job_15116.txt
#   inflating: data/Engineering/Job_18432.txt
#   inflating: __MACOSX/data/Engineering/._Job_18432.txt
#   inflating: data/Engineering/Job_17701.txt
#   inflating: __MACOSX/data/Engineering/._Job_17701.txt
#   inflating: data/Engineering/Job_20032.txt
#   inflating: __MACOSX/data/Engineering/._Job_20032.txt
#   inflating: data/Engineering/Job_17846.txt
#   inflating: __MACOSX/data/Engineering/._Job_17846.txt
#   inflating: data/Engineering/Job_16580.txt
#   inflating: __MACOSX/data/Engineering/._Job_16580.txt
#   inflating: data/Engineering/Job_15089.txt
#   inflating: __MACOSX/data/Engineering/._Job_15089.txt
#   inflating: data/Engineering/Job_14397.txt
#   inflating: __MACOSX/data/Engineering/._Job_14397.txt
#   inflating: data/Engineering/Job_15937.txt
#   inflating: __MACOSX/data/Engineering/._Job_15937.txt
#   inflating: data/Engineering/Job_22143.txt
#   inflating: __MACOSX/data/Engineering/._Job_22143.txt
#   inflating: data/Engineering/Job_20754.txt
#   inflating: __MACOSX/data/Engineering/._Job_20754.txt
#   inflating: data/Engineering/Job_20998.txt
#   inflating: __MACOSX/data/Engineering/._Job_20998.txt
#   inflating: data/Engineering/Job_20740.txt
#   inflating: __MACOSX/data/Engineering/._Job_20740.txt
#   inflating: data/Engineering/Job_15923.txt
#   inflating: __MACOSX/data/Engineering/._Job_15923.txt
#   inflating: data/Engineering/Job_22157.txt
#   inflating: __MACOSX/data/Engineering/._Job_22157.txt
#   inflating: data/Engineering/Job_14383.txt
#   inflating: __MACOSX/data/Engineering/._Job_14383.txt
#   inflating: data/Engineering/Job_20026.txt
#   inflating: __MACOSX/data/Engineering/._Job_20026.txt
#   inflating: data/Engineering/Job_17852.txt
#   inflating: __MACOSX/data/Engineering/._Job_17852.txt
#   inflating: __MACOSX/data/Engineering/._Job_16783.txt
#   inflating: data/Engineering/Job_22426.txt
#   inflating: __MACOSX/data/Engineering/._Job_22426.txt
#   inflating: data/Engineering/Job_15705.txt
#   inflating: __MACOSX/data/Engineering/._Job_15705.txt
#   inflating: data/Engineering/Job_20966.txt
#   inflating: __MACOSX/data/Engineering/._Job_20966.txt
#   inflating: data/Engineering/Job_17112.txt
#   inflating: __MACOSX/data/Engineering/._Job_17112.txt
#   inflating: data/Engineering/Job_18221.txt
#   inflating: __MACOSX/data/Engineering/._Job_18221.txt
#   inflating: data/Engineering/Job_19881.txt
#   inflating: __MACOSX/data/Engineering/._Job_19881.txt
#   inflating: data/Engineering/Job_17674.txt
#   inflating: __MACOSX/data/Engineering/._Job_17674.txt
#   inflating: data/Engineering/Job_18547.txt
#   inflating: __MACOSX/data/Engineering/._Job_18547.txt
#   inflating: data/Engineering/Job_19659.txt
#   inflating: __MACOSX/data/Engineering/._Job_19659.txt
#   inflating: data/Engineering/Job_15063.txt
#   inflating: __MACOSX/data/Engineering/._Job_15063.txt
#   inflating: data/Engineering/Job_15077.txt
#   inflating: __MACOSX/data/Engineering/._Job_15077.txt
#   inflating: data/Engineering/Job_14369.txt
#   inflating: __MACOSX/data/Engineering/._Job_14369.txt
#   inflating: data/Engineering/Job_19895.txt
#   inflating: __MACOSX/data/Engineering/._Job_19895.txt
#   inflating: data/Engineering/Job_17660.txt
#   inflating: __MACOSX/data/Engineering/._Job_17660.txt
#   inflating: data/Engineering/Job_18553.txt
#   inflating: __MACOSX/data/Engineering/._Job_18553.txt
#   inflating: data/Engineering/Job_20972.txt
#   inflating: __MACOSX/data/Engineering/._Job_20972.txt
#   inflating: data/Engineering/Job_16218.txt
#   inflating: __MACOSX/data/Engineering/._Job_16218.txt
#   inflating: data/Engineering/Job_17106.txt
#   inflating: __MACOSX/data/Engineering/._Job_17106.txt
#   inflating: data/Engineering/Job_18235.txt
#   inflating: __MACOSX/data/Engineering/._Job_18235.txt
#   inflating: data/Engineering/Job_15711.txt
#   inflating: __MACOSX/data/Engineering/._Job_15711.txt
#   inflating: data/Engineering/Job_19103.txt
#   inflating: __MACOSX/data/Engineering/._Job_19103.txt
#   inflating: data/Engineering/Job_16230.txt
#   inflating: __MACOSX/data/Engineering/._Job_16230.txt
#   inflating: data/Engineering/Job_20782.txt
#   inflating: __MACOSX/data/Engineering/._Job_20782.txt
#   inflating: data/Engineering/Job_14427.txt
#   inflating: __MACOSX/data/Engineering/._Job_14427.txt
#   inflating: data/Engineering/Job_22195.txt
#   inflating: __MACOSX/data/Engineering/._Job_22195.txt
#   inflating: data/Engineering/Job_15739.txt
#   inflating: __MACOSX/data/Engineering/._Job_15739.txt
#   inflating: data/Engineering/Job_17648.txt
#   inflating: __MACOSX/data/Engineering/._Job_17648.txt
#   inflating: data/Engineering/Job_19665.txt
#   inflating: __MACOSX/data/Engineering/._Job_19665.txt
#   inflating: data/Engineering/Job_16556.txt
#   inflating: __MACOSX/data/Engineering/._Job_16556.txt
#   inflating: data/Engineering/Job_17890.txt
#   inflating: __MACOSX/data/Engineering/._Job_14396.txt
#   inflating: data/Engineering/Job_15088.txt
#   inflating: __MACOSX/data/Engineering/._Job_15088.txt
#   inflating: data/Engineering/Job_16581.txt
#   inflating: __MACOSX/data/Engineering/._Job_16581.txt
#   inflating: data/Engineering/Job_17847.txt
#   inflating: __MACOSX/data/Engineering/._Job_17847.txt
#   inflating: data/Engineering/Job_20033.txt
#   inflating: __MACOSX/data/Engineering/._Job_20033.txt
#   inflating: data/Engineering/Job_20755.txt
#   inflating: __MACOSX/data/Engineering/._Job_20755.txt
#   inflating: data/Engineering/Job_22142.txt
#   inflating: __MACOSX/data/Engineering/._Job_22142.txt
#   inflating: data/Engineering/Job_15936.txt
#   inflating: __MACOSX/data/Engineering/._Job_15936.txt
#   inflating: data/Engineering/Job_15671.txt
#   inflating: __MACOSX/data/Engineering/._Job_15671.txt
#   inflating: data/Engineering/Job_17066.txt
#   inflating: __MACOSX/data/Engineering/._Job_17066.txt
#   inflating: data/Engineering/Job_18355.txt
#   inflating: __MACOSX/data/Engineering/._Job_18355.txt
#   inflating: data/Engineering/Job_16378.txt
#   inflating: __MACOSX/data/Engineering/._Job_16378.txt
#   inflating: data/Engineering/Job_20812.txt
#   inflating: __MACOSX/data/Engineering/._Job_20812.txt
#   inflating: data/Engineering/Job_17700.txt
#   inflating: __MACOSX/data/Engineering/._Job_17700.txt
#   inflating: data/Engineering/Job_18433.txt
#   inflating: __MACOSX/data/Engineering/._Job_18433.txt
#   inflating: data/Engineering/Job_15117.txt
#   inflating: __MACOSX/data/Engineering/._Job_15117.txt
#   inflating: data/Engineering/Job_15103.txt
#   inflating: __MACOSX/data/Engineering/._Job_15103.txt
#   inflating: data/Engineering/Job_19739.txt
#   inflating: __MACOSX/data/Engineering/._Job_19739.txt
#   inflating: data/Engineering/Job_17714.txt
#   inflating: __MACOSX/data/Engineering/._Job_17714.txt
#   inflating: data/Engineering/Job_18427.txt
#   inflating: __MACOSX/data/Engineering/._Job_18427.txt
#   inflating: data/Engineering/Job_17072.txt
#   inflating: __MACOSX/data/Engineering/._Job_17072.txt
#   inflating: data/Engineering/Job_18341.txt
#   inflating: __MACOSX/data/Engineering/._Job_18341.txt
#   inflating: data/Engineering/Job_20806.txt
#   inflating: __MACOSX/data/Engineering/._Job_20806.txt
#   inflating: data/Engineering/Job_15665.txt
#   inflating: __MACOSX/data/Engineering/._Job_15665.txt
#   inflating: data/Engineering/Job_18369.txt
#   inflating: __MACOSX/data/Engineering/._Job_18369.txt
#   inflating: data/Engineering/Job_19077.txt
#   inflating: __MACOSX/data/Engineering/._Job_19077.txt
#   inflating: data/Engineering/Job_16344.txt
#   inflating: __MACOSX/data/Engineering/._Job_16344.txt
#   inflating: data/Engineering/Job_14553.txt
#   inflating: __MACOSX/data/Engineering/._Job_14553.txt
#   inflating: data/Engineering/Job_15895.txt
#   inflating: __MACOSX/data/Engineering/._Job_15895.txt
#   inflating: data/Engineering/Job_19711.txt
#   inflating: __MACOSX/data/Engineering/._Job_19711.txt
#   inflating: data/Engineering/Job_16422.txt
#   inflating: data/Engineering/Job_22535.txt
# ...
#   inflating: data/Engineering/Job_21414.txt
#   inflating: __MACOSX/data/Engineering/._Job_21414.txt
#   inflating: data/Engineering/Job_15969.txt
#   inflating: __MACOSX/data/Engineering/._Job_15969.txt
#   inflating: data/Engineering/Job_21372.txt
#   inflating: __MACOSX/data/Engineering/._Job_21372.txt
#   inflating: data/Engineering/Job_17818.txt
#   inflating: __MACOSX/data/Engineering/._Job_17818.txt
#   inflating: data/Engineering/Job_19835.txt
#   inflating: __MACOSX/data/Engineering/._Job_19835.txt
#   inflating: data/Engineering/Job_17830.txt
#   inflating: __MACOSX/data/Engineering/._Job_17830.txt
#   inflating: data/Engineering/Job_20044.txt
#   inflating: __MACOSX/data/Engineering/._Job_20044.txt
#   inflating: data/Engineering/Job_20722.txt
#   inflating: __MACOSX/data/Engineering/._Job_20722.txt
#   inflating: data/Engineering/Job_16290.txt
#   inflating: __MACOSX/data/Engineering/._Job_16290.txt
#   inflating: data/Engineering/Job_22135.txt
#   inflating: __MACOSX/data/Engineering/._Job_22135.txt
#   inflating: data/Engineering/Job_15799.txt
#   inflating: __MACOSX/data/Engineering/._Job_15799.txt
#   inflating: data/Engineering/Job_15941.txt
#   inflating: __MACOSX/data/Engineering/._Job_15941.txt
#   inflating: data/Engineering/Job_14487.txt
#   inflating: __MACOSX/data/Engineering/._Job_14487.txt
#   inflating: data/Engineering/Job_22121.txt
#   inflating: __MACOSX/data/Engineering/._Job_22121.txt
#   inflating: data/Engineering/Job_15955.txt
#   inflating: __MACOSX/data/Engineering/._Job_15955.txt
#   inflating: data/Engineering/Job_14493.txt
#   inflating: __MACOSX/data/Engineering/._Job_14493.txt
#   inflating: data/Engineering/Job_20736.txt
#   inflating: __MACOSX/data/Engineering/._Job_20736.txt
#   inflating: data/Engineering/Job_21428.txt
#   inflating: __MACOSX/data/Engineering/._Job_21428.txt
#   inflating: data/Engineering/Job_16284.txt
#   inflating: __MACOSX/data/Engineering/._Job_16284.txt
#   inflating: data/Engineering/Job_17824.txt
#   inflating: __MACOSX/data/Engineering/._Job_17824.txt
#   inflating: data/Engineering/Job_19809.txt
#   inflating: __MACOSX/data/Engineering/._Job_19809.txt
#   inflating: data/Engineering/Job_20050.txt
#   inflating: __MACOSX/data/Engineering/._Job_20050.txt
#   inflating: data/Engineering/Job_15174.txt
#   inflating: __MACOSX/data/Engineering/._Job_15174.txt
#   inflating: data/Engineering/Job_18450.txt
#   inflating: __MACOSX/data/Engineering/._Job_18450.txt
#   inflating: data/Engineering/Job_17763.txt
#   inflating: __MACOSX/data/Engineering/._Job_17763.txt
#   inflating: data/Engineering/Job_19996.txt
#   inflating: __MACOSX/data/Engineering/._Job_19996.txt
#   inflating: data/Engineering/Job_18336.txt
#   inflating: __MACOSX/data/Engineering/._Job_18336.txt
#   inflating: data/Engineering/Job_17005.txt
#   inflating: __MACOSX/data/Engineering/._Job_17005.txt
#   inflating: data/Engineering/Job_19028.txt
#   inflating: __MACOSX/data/Engineering/._Job_19028.txt
#   inflating: data/Engineering/Job_20871.txt
#   inflating: __MACOSX/data/Engineering/._Job_19766.txt
#   inflating: data/Engineering/Job_18478.txt
#   inflating: __MACOSX/data/Engineering/._Job_18478.txt
#   inflating: data/Engineering/Job_18493.txt
#   inflating: __MACOSX/data/Engineering/._Job_18493.txt
#   inflating: data/Engineering/Job_19955.txt
#   inflating: __MACOSX/data/Engineering/._Job_19955.txt
#   inflating: data/Engineering/Job_17978.txt
#   inflating: __MACOSX/data/Engineering/._Job_17978.txt
#   inflating: data/Engineering/Job_21212.txt
#   inflating: __MACOSX/data/Engineering/._Job_21212.txt
#   inflating: data/Engineering/Job_15809.txt
#   inflating: __MACOSX/data/Engineering/._Job_15809.txt
#   inflating: data/Engineering/Job_21574.txt
#   inflating: __MACOSX/data/Engineering/._Job_21574.txt
#   inflating: data/Engineering/Job_21560.txt
#   inflating: __MACOSX/data/Engineering/._Job_21560.txt
#   inflating: data/Engineering/Job_22069.txt
#   inflating: __MACOSX/data/Engineering/._Job_22069.txt
#   inflating: data/Engineering/Job_18487.txt
#   inflating: __MACOSX/data/Engineering/._Job_18487.txt
#   inflating: data/Engineering/Job_20118.txt
#   inflating: __MACOSX/data/Engineering/._Job_20118.txt
#   inflating: data/Engineering/Job_19941.txt
#   inflating: __MACOSX/data/Engineering/._Job_19941.txt
#   inflating: data/Engineering/Job_19799.txt
#   inflating: __MACOSX/data/Engineering/._Job_19799.txt
#   inflating: data/Engineering/Job_21206.txt
#   inflating: __MACOSX/data/Engineering/._Job_21206.txt
#   inflating: data/Engineering/Job_20130.txt
#   inflating: __MACOSX/data/Engineering/._Job_20130.txt
#   inflating: data/Engineering/Job_19969.txt
#   inflating: __MACOSX/data/Engineering/._Job_19969.txt
#   inflating: data/Engineering/Job_17944.txt
#   inflating: __MACOSX/data/Engineering/._Job_17944.txt
#   inflating: data/Engineering/Job_16482.txt
#   inflating: __MACOSX/data/Engineering/._Job_16482.txt
#   inflating: data/Engineering/Job_21548.txt
#   inflating: __MACOSX/data/Engineering/._Job_21548.txt
#   inflating: data/Engineering/Job_20656.txt
#   inflating: __MACOSX/data/Engineering/._Job_20656.txt
#   inflating: data/Engineering/Job_15835.txt
#   inflating: __MACOSX/data/Engineering/._Job_15835.txt
#   inflating: data/Engineering/Job_22041.txt
#   inflating: __MACOSX/data/Engineering/._Job_22041.txt
#   inflating: data/Engineering/Job_15821.txt
#   inflating: __MACOSX/data/Engineering/._Job_15821.txt
#   inflating: data/Engineering/Job_22055.txt
#   inflating: __MACOSX/data/Engineering/._Job_22055.txt
#   inflating: data/Engineering/Job_20642.txt
#   inflating: __MACOSX/data/Engineering/._Job_20642.txt
#   inflating: data/Engineering/Job_20124.txt
#   inflating: __MACOSX/data/Engineering/._Job_20124.txt
#   inflating: data/Engineering/Job_17788.txt
#   inflating: __MACOSX/data/Engineering/._Job_17788.txt
#   inflating: data/Engineering/Job_17950.txt
#   inflating: __MACOSX/data/Engineering/._Job_17950.txt
#   inflating: data/Engineering/Job_16496.txt
#   inflating: __MACOSX/data/Engineering/._Job_16496.txt
#   inflating: data/Engineering/Job_15410.txt
#   inflating: __MACOSX/data/Engineering/._Job_15410.txt
#   inflating: data/Engineering/Job_16119.txt
#   inflating: __MACOSX/data/Engineering/._Job_16119.txt
#   inflating: data/Engineering/Job_17207.txt
#   inflating: __MACOSX/data/Engineering/._Job_17207.txt
#   inflating: data/Engineering/Job_18134.txt
#   inflating: __MACOSX/data/Engineering/._Job_18134.txt
#   inflating: data/Engineering/Job_17561.txt
#   inflating: __MACOSX/data/Engineering/._Job_17561.txt
#   inflating: data/Engineering/Job_18652.txt
#   inflating: __MACOSX/data/Engineering/._Job_18652.txt
#   inflating: data/Engineering/Job_15376.txt
#   inflating: __MACOSX/data/Engineering/._Job_15376.txt
#   inflating: data/Engineering/Job_15362.txt
#   inflating: __MACOSX/data/Engineering/._Job_15362.txt
#   inflating: data/Engineering/Job_17575.txt
#   inflating: __MACOSX/data/Engineering/._Job_17575.txt
#   inflating: data/Engineering/Job_18646.txt
#   inflating: __MACOSX/data/Engineering/._Job_18646.txt
#   inflating: data/Engineering/Job_19558.txt
#   inflating: __MACOSX/data/Engineering/._Job_19558.txt
#   inflating: data/Engineering/Job_17213.txt
#   inflating: __MACOSX/data/Engineering/._Job_17213.txt
#   inflating: data/Engineering/Job_18120.txt
#   inflating: __MACOSX/data/Engineering/._Job_18120.txt
#   inflating: data/Engineering/Job_21979.txt
#   inflating: __MACOSX/data/Engineering/._Job_21979.txt
#   inflating: data/Engineering/Job_15404.txt
#   inflating: __MACOSX/data/Engineering/._Job_15404.txt
#   inflating: data/Engineering/Job_19216.txt
#   inflating: __MACOSX/data/Engineering/._Job_19216.txt
#   inflating: data/Engineering/Job_21789.txt
#   inflating: __MACOSX/data/Engineering/._Job_21789.txt
#   inflating: data/Engineering/Job_16125.txt
#   inflating: __MACOSX/data/Engineering/._Job_16125.txt
#   inflating: data/Engineering/Job_18108.txt
#   inflating: __MACOSX/data/Engineering/._Job_18108.txt
#   inflating: data/Engineering/Job_20497.txt
#   inflating: __MACOSX/data/Engineering/._Job_20497.txt
#   inflating: data/Engineering/Job_21951.txt
#   inflating: __MACOSX/data/Engineering/._Job_21951.txt
#   inflating: data/Engineering/Job_14732.txt
#   inflating: __MACOSX/data/Engineering/._Job_14732.txt
#   inflating: data/Engineering/Job_22280.txt
#   inflating: __MACOSX/data/Engineering/._Job_22280.txt
#   inflating: data/Engineering/Job_19570.txt
#   inflating: __MACOSX/data/Engineering/._Job_19570.txt
#   inflating: data/Engineering/Job_16643.txt
#   inflating: __MACOSX/data/Engineering/._Job_16643.txt
#   inflating: data/Engineering/Job_17549.txt
#   inflating: __MACOSX/data/Engineering/._Job_17549.txt
#   inflating: data/Engineering/Job_19564.txt
#   inflating: __MACOSX/data/Engineering/._Job_19564.txt
#   inflating: data/Engineering/Job_16657.txt
#   inflating: __MACOSX/data/Engineering/._Job_16657.txt
#   inflating: data/Engineering/Job_14726.txt
#   inflating: __MACOSX/data/Engineering/._Job_14726.txt
#   inflating: data/Engineering/Job_22294.txt
#   inflating: __MACOSX/data/Engineering/._Job_22294.txt
#   inflating: data/Engineering/Job_15438.txt
#   inflating: __MACOSX/data/Engineering/._Job_15438.txt
#   inflating: data/Engineering/Job_19202.txt
#   inflating: __MACOSX/data/Engineering/._Job_19202.txt
#   inflating: data/Engineering/Job_16131.txt
#   inflating: __MACOSX/data/Engineering/._Job_16131.txt
#   inflating: data/Engineering/Job_20483.txt
#   inflating: __MACOSX/data/Engineering/._Job_20483.txt
#   inflating: data/Engineering/Job_21945.txt
#   inflating: __MACOSX/data/Engineering/._Job_21945.txt
#   inflating: data/Engineering/Job_20468.txt
#   inflating: __MACOSX/data/Engineering/._Job_20468.txt
#   inflating: data/Engineering/Job_21776.txt
#   inflating: __MACOSX/data/Engineering/._Job_21776.txt
#   inflating: data/Engineering/Job_14915.txt
#   inflating: __MACOSX/data/Engineering/._Job_14915.txt
#   inflating: data/Engineering/Job_22519.txt
#   inflating: __MACOSX/data/Engineering/._Job_22519.txt
#   inflating: data/Engineering/Job_21010.txt
#   inflating: __MACOSX/data/Engineering/._Job_21010.txt
#   inflating: data/Engineering/Job_18849.txt
#   inflating: __MACOSX/data/Engineering/._Job_18849.txt
#   inflating: data/Engineering/Job_16864.txt
#   inflating: __MACOSX/data/Engineering/._Job_16864.txt
#   inflating: data/Engineering/Job_18691.txt
#   inflating: __MACOSX/data/Engineering/._Job_18691.txt
#   inflating: data/Engineering/Job_21004.txt
#   inflating: __MACOSX/data/Engineering/._Job_21004.txt
#   inflating: data/Engineering/Job_16870.txt
#   inflating: __MACOSX/data/Engineering/._Job_16870.txt
#   inflating: data/Engineering/Job_18685.txt
#   inflating: __MACOSX/data/Engineering/._Job_18685.txt
#   inflating: data/Engineering/Job_14901.txt
#   inflating: __MACOSX/data/Engineering/._Job_14901.txt
#   inflating: data/Engineering/Job_21762.txt
#   inflating: __MACOSX/data/Engineering/._Job_21762.txt
#   inflating: data/Engineering/Job_22243.txt
#   inflating: __MACOSX/data/Engineering/._Job_22243.txt
#   inflating: data/Engineering/Job_14929.txt
#   inflating: __MACOSX/data/Engineering/._Job_14929.txt
#   inflating: data/Engineering/Job_20454.txt
#   inflating: __MACOSX/data/Engineering/._Job_20454.txt
#   inflating: data/Engineering/Job_21992.txt
#   inflating: __MACOSX/data/Engineering/._Job_21992.txt
#   inflating: data/Engineering/Job_16680.txt
#   inflating: __MACOSX/data/Engineering/._Job_16680.txt
#   inflating: data/Engineering/Job_18875.txt
#   inflating: __MACOSX/data/Engineering/._Job_18875.txt
#   inflating: data/Engineering/Job_16858.txt
#   inflating: __MACOSX/data/Engineering/._Job_16858.txt
#   inflating: data/Engineering/Job_20332.txt
#   inflating: __MACOSX/data/Engineering/._Job_20332.txt
#   inflating: data/Engineering/Job_22525.txt
#   inflating: __MACOSX/data/Engineering/._Job_22525.txt
#   inflating: data/Engineering/Job_15389.txt
#   inflating: __MACOSX/data/Engineering/._Job_15389.txt
#   inflating: data/Engineering/Job_22531.txt
#   inflating: __MACOSX/data/Engineering/._Job_22531.txt
#   inflating: data/Engineering/Job_21038.txt
#   inflating: __MACOSX/data/Engineering/._Job_21038.txt
#   inflating: data/Engineering/Job_16694.txt
#   inflating: __MACOSX/data/Engineering/._Job_16694.txt
#   inflating: data/Engineering/Job_18861.txt
#   inflating: __MACOSX/data/Engineering/._Job_18861.txt
#   inflating: data/Engineering/Job_20326.txt
#   inflating: __MACOSX/data/Engineering/._Job_20326.txt
#   inflating: data/Engineering/Job_20440.txt
#   inflating: __MACOSX/data/Engineering/._Job_20440.txt
#   inflating: data/Engineering/Job_21986.txt
#   inflating: __MACOSX/data/Engineering/._Job_21986.txt
#   inflating: data/Engineering/Job_22257.txt
#   inflating: __MACOSX/data/Engineering/._Job_22257.txt

# %%
# required Libraries
from sklearn.datasets import load_files
from nltk import RegexpTokenizer
from nltk.tokenize import sent_tokenize
from itertools import chain
import re
import nltk
from nltk.tokenize.treebank import TreebankWordDetokenizer
nltk.download('punkt')
from nltk.probability import *
from nltk.util import ngrams
import pickle
import os
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ### 1. Examining and loading data

# %%
rawData = load_files(r"data", load_content=True, encoding= 'utf-8')

# %%
# storing the stopwords from stopwords_en.txt in a list
stopwords = []
with open('/content/drive/My Drive/stopwords_en.txt', encoding='utf-8') as f:
    stopwords = f.read().splitlines()

# %%
# create list with ID
def getNewList(rawData):
  # initialise list
  lines = list()
  # regex to get digits of ID
  regex = re.compile(r'\d+')
  for index, line in enumerate(rawData.data):   
    # find digits from the line
    id = regex.findall(rawData.filenames[index])
    id = ''.join(id)
    # appending ID with the required format
    lines.append("ID: " + id)
    category = os.path.basename(os.path.dirname(rawData.filenames[index]))
    # appending category from the folder name
    lines.append("Category: " + category)
    for word in line.split("\n"):
      # append all the lines
      lines.append(word)
  
  return lines

# getNewList
newlist = getNewList(rawData)
newlist[1:10]
# Out:
# ['Category: Engineering',
#  'Title: Plant Engineer',
#  'Webindex: 62119057',
#  'Company: W5 Recruitment',
#  "Description: Our client has established itself as a leading manufacturer and supplier of quality water treatment plants, ranging from basic water softeners and reverse osmosis equipment to customer specified complex water treatment solutions. The company are able to meet their clients' requirements through flexibility in tailoring their product to their needs and budgets. Due to expansion and an increased workload they are seeking to recruit a Planet Engineer to cover accounts along the M4 Corridor Responsibilities will include conducting the routine sampling and analysis of water systems, interpreting results, maintenance and the installation of chemical dosing systems. Servicing accounts within both the industrial and commercial industries the successful candidate will complete all work in accordance to the approved code of practice. The ideal applicant for this position will have a minimum of two years relevant industry experience and will have knowledge of reverse osmosis, water softeners, water filters and UV equipment. A full UK driving license is essential. In return the client is offering a competitive benefits and salary package to the ideal candidate.",
#  'ID: 31567',
#  'Category: Healthcare_Nursing',
#  'Title: Residential Care Worker',
#  'Webindex: 66314490']

# %% [markdown]
# ### 2. Tokenize each job advertisement description

# %%
def tokenizeDescription(raw_description):
  raw_description = lowerCase(raw_description)
  # tokenize raw description
  sentences = sent_tokenize(raw_description)
  # required regex pattern for the strings
  pattern = r"[a-zA-Z]+(?:[-'][a-zA-Z]+)?"
  # tokenize strings with above regex pattern
  tokenizer = RegexpTokenizer(pattern)
  # return tokenized words in form of list
  token_lists = [tokenizer.tokenize(sen) for sen in sentences]
  # merging into a list of tokens
  tokenizeDescription = list(chain.from_iterable(token_lists))
  return tokenizeDescription

# %% [markdown]
# ### 3. Convert words to lower case

# %%
def lowerCase(raw_description):
  # convert all strings in the description to lower case
  raw_description = raw_description.lower()
  # get the first character of first string i.e., d
  newstr = raw_description[0]
  # capitalize 'd' of description to meet the required format
  newstr = newstr.upper()
  # Description + other lower strings
  my_string = newstr + raw_description[1:]
  return my_string

# %% [markdown]
# ### 4. Remove words with length less than 2

# %%
def remove_short_words(tokens):
  # list without short words
  new_tokens = list()
  for t in tokens:
    if len(t) >= 2:
      # append words with length more than 2
      new_tokens.append(t)
  return new_tokens

# %% [markdown]
# ### 5. Remove stopwords using the provided stop words list

# %%
def removeStopWords(match):
  # initialise list
  list_without_stopwords = list()
  for word in match:
    if word not in stopwords:
      # append words which are not in the stopwords list
      list_without_stopwords.append(word)
  return list_without_stopwords

# %% [markdown]
# ### 6. Remove the word that appears only once in the document collection(TERM FREQUENCY)

# %%
def findTermFreqWords(descList):
  # creating a chainable list of all description tokens
  allDescWordList = list(chain.from_iterable(descList))
  # calculating the term frequency distribution
  term_fd = FreqDist(allDescWordList)
  # list of all leff frequent words
  lessFreqWords = set(term_fd.hapaxes())
  return lessFreqWords

def removeLessFreqWordTokens(tokens, lessFreqWords):
  # looping through and returing a list without less frequent words
  return [w for w in tokens if w not in lessFreqWords]

# %% [markdown]
# ### 7. Remove the top 50 most frequent words(DOCUMENT FREQUENCY)

# %%
def removeDocFreqWords(tokens, top50words):
  # looping through and returing a list without top 50 most frequent words
  return [w for w in tokens if w not in top50words]

# %% [markdown]
# ### Executing all above functions

# %%
# function for task 1-5
def main1(newlist):
  # initialise list
  newList2 = list()
  
  # looping through all the lines of list
  for match in newlist:
    # condiiton to check if index 0 of the line starts with "Description"
    if match.find("Description") == 0:
      # tokenize each description string
      tokenized = tokenizeDescription(match)

      # remove short words from the above tokens
      tokenized = remove_short_words(tokenized)
      
      # remove stop words from the above tokens
      match1 = removeStopWords(tokenized) 

      # detokenizing the processed tokens
      match2 = TreebankWordDetokenizer().detokenize(match1)

      # add colon after Description keyword for required format
      match2 = match2[:11] + ":" + match2[11:]

      # append the string to the list
      newList2.append(match2)

    # condiiton to check if index 0 of the line starts with "Company"
    elif match.find("Company") == 0:
      # skipping as Company is not required
      continue
    # appending all other lines
    else:
      newList2.append(match)
  return newList2


newList2 = main1(newlist)

# %%
newList2[1:10]
# Out:
# ['Category: Engineering',
#  'Title: Plant Engineer',
#  'Webindex: 62119057',
#  'Description: client established leading manufacturer supplier quality water treatment plants ranging basic water softeners reverse osmosis equipment customer complex water treatment solutions company meet clients requirements flexibility tailoring product budgets due expansion increased workload seeking recruit planet engineer cover accounts corridor responsibilities include conducting routine sampling analysis water systems interpreting results maintenance installation chemical dosing systems servicing accounts industrial commercial industries successful candidate complete work accordance approved code practice ideal applicant position minimum years relevant industry experience knowledge reverse osmosis water softeners water filters uv equipment full uk driving license essential return client offering competitive benefits salary package ideal candidate',
#  'ID: 31567',
#  'Category: Healthcare_Nursing',
#  'Title: Residential Care Worker',
#  'Webindex: 66314490',
#  'Description: timeout children homes rapidly expanding company forefront therapeutic care young people aged years experienced emotional behavioural difficulties lives recruit residential care workers based homes swindon area successful candidates work collaboratively cooperatively timeout staff young people external agencies required work consultation families social workers yot professionals involved young person including education team deliver effective educational programmes successful applicants required provide enhanced disclosure disclosure expense met employer apply click apply button redirected site complete application form']

# %%
# function to return tokens of all the description
def getAllDescList(newlist):
  # initialise list
  desList = list()

  # looping through all the lines of list
  for match in newlist:
    # condiiton to check if index 0 of the line starts with "Description"
    if match.find("Description") == 0:
      # tokenize each description string
      tokens = tokenizeDescription(match)
      tokens.remove('Description')
      # appending all the tokens
      desList.append(tokens)

  # print("desList: getAllDescList  ", desList)
  return desList

# %%
#  function to iterate through rocessed list and remove less frequent words
def removeLessFreqWords(prevList):
  newList = list()
  allDescListTokens = getAllDescList(prevList)
  lessFreqWords = findTermFreqWords(allDescListTokens)
  # print("lessFreqWords:--------",lessFreqWords)
  
  # looping through all the lines of list
  for match in prevList:
    # condiiton to check if index 0 of the line starts with "Description"
    if match.find("Description") == 0:
      # tokenize each description string
      tokenized = tokenizeDescription(match)
      
      # remove less frequent words from the above tokens
      lessFreqWordsRemoved = removeLessFreqWordTokens(tokenized, lessFreqWords) 
      
      # detokenizing the processed tokens
      detokenized = TreebankWordDetokenizer().detokenize(lessFreqWordsRemoved)
      
      # add colon after Description keyword for required format
      detokenized = detokenized[:11] + ":" + detokenized[11:]
      
      # append the string to the list
      newList.append(detokenized)      
    
    # condiiton to check if index 0 of the line starts with "Company"
    elif match.find("Company") == 0:
      # skipping as Company is not required
      continue
    # appending all other lines   
    else:    
      newList.append(match)

  return newList

# %%
# run function to remove less frequent words
ListWithoutLessFreq = removeLessFreqWords(newList2)
# Out:
# desList: getAllDescList
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# lessFreqWords:-------- {'nonvendor', 'microbrewery', 'financialplannerbirmingham', 'aunch', 'asapref', 'salesexecutivefieldsalesareasales', 'ibmi', 'managerexciting', 'salisburyour', 'invernessscotland', 'researchinformed', 'unorthodox', 'serviceptr', 'yorksalary', 'delegatedauthoritydataanalyst', 'cwc', 'nurser', 'stricktest', 'liant', 'maintenanceengineershiftengineerelectricalengineer', 'foundationlevel', 'developerlinux', 'swbacademyhays', 'brightside', 'husky', 'presentationsmanage', 'acareportingaccountant', 'dervers', 'pastrychefal', 'abitity', 'nationallyrecognised', 'metown', 'polarrecruitment', 'haematologists', 'systme', 'bonusduration', 'enob', 'applcations', 'encashments', 'newbusinesssalesaccountexective', 'ecommercebusinessanalystretailbackground', 'responsibilitiespa', 'hippa', 'graduateitsales', 'fixedincomesingledealersupportanalyst', 'accountnegotiator', 'multivenue', 'jobsfairs', 'primaryschoolteacherleeds', 'investmentmanagementsales', 'secteur', 'nickaaslrecruitment', 'accountsjuniorpartaatq', 'itservicedeskanalsyt', "rfi'sproject", 'inscriptions', 'enquiriesexcitecare', 'postgre', 'motivatelarge', 'javascriptfrontenddeveloper', 'fess', "lion's", 'fiscals', 'managercv', 'forecastingplanning', 'serverexcellent', 'supersmart', 'presentationspecialisteveningshift', 'qdip', 'tvc', 'mumbles', 'hauling', 'securitysystemsengineer', 'ukwidedue', 'ericson', 'dependidng', 'rosettenorth', 'iosapplicationdeveloper', 'xamine', 'bolisau', 'pillows', 'broadberryrisetechnical', 'mostcompetitive', 'weekall', 'aspnetwebdeveloper', 'nearwarringtonincheshire', 'managementstakeholder', 'organistions', 'seniorjavadeveloperjavaspringhibernate', 'redworth', 'recruitmentconsultantseniorrecruitmentconsultantmanager', 'experiencedchefdepartiewanted', 'caddy', 'goodsinwardsiso', 'avitsupporttechnician', 'assetliability', 'westwards', 'quantitativeresearchassociateexcellentpackagebase', 'hindlip', 'developmentteamleaderleicestershire', 'productbuildstate', 'accountmanagernorth', 'evts', 'andsignoff', 'secondarily', 'siperian', 'firma', 'nursequalified', 'planundertaking', 'suppercookmaternitycover', 'projectmanagerassetmanagementcity', 'multiemea', 'digitalaccountmanagerportuguesespanishspeaking', 'marketingcommunicationsassistantwithdigitalexperience', 'businessdevelopmentmanagerexperianautomotivematernitycover', 'abab', 'newbusinesssalesconsultantbusinesssolutions', 'lettingsmanagerwatford', 'bou', 'completedthis', 'opopulusconsultants', 'currentgen', 'sdesign', 'nota', 'campain', 'consensusbuilding', 'brokendown', 'souschefawardwinningrosettediningleics', 'solutionsadaptable', 'bulloversee', 'quothandson', 'darrenfootballexecutives', 'deflection', 'marinemanagement', 'thelondonbridgearea', 'barsmanagercountryrestaurantandeventvenue', 'essentialgood', 'firstclassconcepts', 'swtel', 'telesalesmarketingexecutive', 'installationskey', 'securityoperationsanalyst', 'marketingproductexecutive', 'reschedule', 'otivated', 'changesleading', 'ambitiousebdteacherrequiredinherefordshire', 'osteopathic', 'oppoertunities', 'javaseniordeveloperj', 'seniorunixadministratorteamleader', 'thesystems', 'seniorbusinessmanagerappledivision', 'phwest', 'seniormechanicalengineeranalysisautomotive', 'stafflocation', "dealership's", 'ommunity', 'riskmananger', 'leiston', 'backgroundm', 'predomiantly', 'digitaldeliveryusabilityandaccessibilitymanager', 'juniorrecruitmentconsultanttecheng', 'antibiotic', 'inforce', 'voornamelijk', 'seniorbusinessdevelopmentmanagerwithinit', 'disabailities', 'apexformsreports', 'lyrical', 'datasift', 'regionalmanagerretail', 'caton', 'nursesour', 'burj', 'frith', 'mechanicalmaintenanceengineer', 'regionalsalesexecutivenorthwest', 'flexserver', 'informationproduce', 'banklink', 'palms', 'jobsharing', 'slower', 'expertderbyshire', 'funtley', 'evalution', 'literatedue', 'locationbristol', "consumer's", 'accuratively', 'marrakesh', 'chrismaseynrgplc', 'qatesterleadingdigitalagency', 'reportingproviding', 'jeder', 'eventssalesmanag ...

# %% [markdown]
# ### Top 50 words

# %%
# run function to get all description tokens in a list
allDescListTokens = getAllDescList(ListWithoutLessFreq)
# Out:
# desList: getAllDescList
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# This is a nested list of all description tokens
allDescListTokens[1:3]
# Out:
# [['timeout',
#   'children',
#   'homes',
#   'rapidly',
#   'expanding',
#   'company',
#   'forefront',
#   'therapeutic',
#   'care',
#   'young',
#   'people',
#   'aged',
#   'years',
#   'experienced',
#   'emotional',
#   'behavioural',
#   'difficulties',
#   'lives',
#   'recruit',
#   'residential',
#   'care',
#   'workers',
#   'based',
#   'homes',
#   'swindon',
#   'area',
#   'successful',
#   'candidates',
#   'work',
#   'collaboratively',
#   'cooperatively',
#   'timeout',
#   'staff',
#   'young',
#   'people',
#   'external',
#   'agencies',
#   'required',
#   'work',
#   'consultation',
#   'families',
#   'social',
#   'workers',
#   'yot',
#   'professionals',
#   'involved',
#   'young',
#   'person',
#   'including',
#   'education',
#   'team',
#   'deliver',
#   'effective',
#   'educational',
#   'programmes',
#   'successful',
#   'applicants',
#   'required',
#   'provide',
#   'enhanced',
#   'disclosure',
#   'disclosure',
#   'expense',
#   'met',
#   'employer',
#   'apply',
#   'click',
#   'apply',
#   'button',
#   'redirected',
#   'site',
#   'complete',
#   'application',
#   'form'],
#  ['french',
#   'restaurant',
#   'club',
#   'gascon',
#   'michelin',
#   'established',
#   'heart',
#   'london',
#   'easy',
#   'access',
#   'bus',
#   'train',
#   'tube',
#   'experienced',
#   'chef',
#   'de',
#   'rang',
#   'waiter',
#   'complete',
#   'team',
#   'split',
#   'straight',
#   'shifts',
#   'depending',
#   'rota',
#   'days',
#   'week',
#   'closed',
#   'sunday',
#   'bank',
#   'holiday',
#   'average',
#   'week',
#   'real',
#   'career',
#   'progression',
#   'part',
#   'small',
#   'group',
#   'quality',
#   'restaurant',
#   'based',
#   'london',
#   'excellent',
#   'wages',
#   'basic',
#   'share',
#   'gratuities',
#   'staff',
#   'discount',
#   'restaurants',
#   'check',
#   'site',
#   'www',
#   'clubgascon',
#   'interested',
#   'joining',
#   'send',
#   'detailed',
#   'cv',
#   'position',
#   'applied',
#   'arrange',
#   'meeting',
#   'order',
#   'discuss',
#   'position',
#   'offer']]

# %%
# get only top 50 words from the set
allDescWords = list(chain.from_iterable([set(w) for w in allDescListTokens]))
# document frequency for each unique word/type from the description
doc_fd = FreqDist(allDescWords)
# most common function to get top 50 set
doc_fd.most_common(50)
# Out:
# [('experience', 43644),
#  ('role', 34680),
#  ('work', 33684),
#  ('team', 32585),
#  ('working', 30714),
#  ('skills', 30412),
#  ('client', 26899),
#  ('job', 25552),
#  ('business', 24739),
#  ('uk', 24133),
#  ('excellent', 22982),
#  ('opportunity', 22678),
#  ('company', 22263),
#  ('management', 20620),
#  ('required', 20555),
#  ('development', 20223),
#  ('apply', 20133),
#  ('based', 19333),
#  ('successful', 19118),
#  ('join', 18682),
#  ('www', 18421),
#  ('salary', 18402),
#  ('cv', 18383),
#  ('support', 18286),
#  ('knowledge', 17844),
#  ('strong', 16475),
#  ('environment', 16408),
#  ('posted', 16398),
#  ('jobseeking', 16342),
#  ('candidate', 16304),
#  ('originally', 16294),
#  ('leading', 16194),
#  ('high', 15922),
#  ('service', 15623),
#  ('manager', 15587),
#  ('good', 15252),
#  ('ability', 15154),
#  ('including', 14857),
#  ('position', 14564),
#  ('services', 14501),
#  ('benefits', 14434),
#  ('training', 14218),
#  ('essential', 13915),
#  ('experienced', 13826),
#  ('key', 13567),
#  ('contact', 13551),
#  ('level', 13523),
#  ('recruitment', 13518),
#  ('candidates', 13462),
#  ('provide', 13204)]

# %%
# list of top 50 word tokens
top50words = set(w[0] for w in doc_fd.most_common(50))
top50words
# Out:
# {'ability',
#  'apply',
#  'based',
#  'benefits',
#  'business',
#  'candidate',
#  'candidates',
#  'client',
#  'company',
#  'contact',
#  'cv',
#  'development',
#  'environment',
#  'essential',
#  'excellent',
#  'experience',
#  'experienced',
#  'good',
#  'high',
#  'including',
#  'job',
#  'jobseeking',
#  'join',
#  'key',
#  'knowledge',
#  'leading',
#  'level',
#  'management',
#  'manager',
#  'opportunity',
#  'originally',
#  'position',
#  'posted',
#  'provide',
#  'recruitment',
#  'required',
#  'role',
#  'salary',
#  'service',
#  'services',
#  'skills',
#  'strong',
#  'successful',
#  'support',
#  'team',
#  'training',
#  'uk',
#  'work',
#  'working',
#  'www'}

# %%
# function to remove top 50 words from the description
def removeTop50Words(prevList, top50words):
  #  initialise list
  newList = list()

  # looping through all the lines of list
  for match in prevList:
    # condiiton to check if index 0 of the line starts with "Description"
    if match.find("Description") == 0: 
      # tokenize each description string
      tokenized = tokenizeDescription(match)
      
      # run function to remove top 50 words based on document frequency
      topFiftyRemoved = removeDocFreqWords(tokenized, top50words)

      # detokenizing the processed tokens
      detokenized = TreebankWordDetokenizer().detokenize(topFiftyRemoved)
      
      # add colon after Description keyword for required format
      detokenized = detokenized[:11] + ":" + detokenized[11:]

      # append the string to the list
      newList.append(detokenized)
    
    # appending all other lines 
    else:    
      newList.append(match)

  return newList

# %%
# run function to remove top 50 words
ListWithoutTop50Words = removeTop50Words(ListWithoutLessFreq, top50words)

# %%
ListWithoutTop50Words[1:10]
# Out:
# ['Category: Engineering',
#  'Title: Plant Engineer',
#  'Webindex: 62119057',
#  'Description: established manufacturer supplier quality water treatment plants ranging basic water softeners reverse osmosis equipment customer complex water treatment solutions meet clients requirements flexibility tailoring product budgets due expansion increased workload seeking recruit planet engineer cover accounts corridor responsibilities include conducting routine sampling analysis water systems interpreting results maintenance installation chemical dosing systems servicing accounts industrial commercial industries complete accordance approved code practice ideal applicant minimum years relevant industry reverse osmosis water softeners water filters uv equipment full driving license return offering competitive package ideal',
#  'ID: 31567',
#  'Category: Healthcare_Nursing',
#  'Title: Residential Care Worker',
#  'Webindex: 66314490',
#  'Description: timeout children homes rapidly expanding forefront therapeutic care young people aged years emotional behavioural difficulties lives recruit residential care workers homes swindon area collaboratively cooperatively timeout staff young people external agencies consultation families social workers yot professionals involved young person education deliver effective educational programmes applicants enhanced disclosure disclosure expense met employer click button redirected site complete application form']

# %%
# storing the final list in a new variable
finalJobAds = ListWithoutTop50Words

# %%
# Pickle out finalJobAds list
pickle_out = open("/content/drive/My Drive/pickle-data/finalJobAds.pickle", "wb")
pickle.dump(finalJobAds, pickle_out)

# %%
# Pickle in finalJobAds list
pickle_in = open("/content/drive/My Drive/pickle-data/finalJobAds.pickle", "rb")
finalJobAds = pickle.load(pickle_in)

# %%
finalJobAds[1:15]
# Out:
# ['Category: Engineering',
#  'Title: Plant Engineer',
#  'Webindex: 62119057',
#  'Description: established manufacturer supplier quality water treatment plants ranging basic water softeners reverse osmosis equipment customer complex water treatment solutions meet clients requirements flexibility tailoring product budgets due expansion increased workload seeking recruit planet engineer cover accounts corridor responsibilities include conducting routine sampling analysis water systems interpreting results maintenance installation chemical dosing systems servicing accounts industrial commercial industries complete accordance approved code practice ideal applicant minimum years relevant industry reverse osmosis water softeners water filters uv equipment full driving license return offering competitive package ideal',
#  'ID: 31567',
#  'Category: Healthcare_Nursing',
#  'Title: Residential Care Worker',
#  'Webindex: 66314490',
#  'Description: timeout children homes rapidly expanding forefront therapeutic care young people aged years emotional behavioural difficulties lives recruit residential care workers homes swindon area collaboratively cooperatively timeout staff young people external agencies consultation families social workers yot professionals involved young person education deliver effective educational programmes applicants enhanced disclosure disclosure expense met employer click button redirected site complete application form',
#  'ID: 50131',
#  'Category: Hospitality_Catering',
#  'Title: CHEF DE RANG FOR MICHELIN STARRED RESTAURANT',
#  'Webindex: 69182387',
#  'Description: french restaurant club gascon michelin established heart london easy access bus train tube chef de rang waiter complete split straight shifts depending rota days week closed sunday bank holiday average week real career progression part small group quality restaurant london wages basic share gratuities staff discount restaurants check site clubgascon interested joining send detailed applied arrange meeting order discuss offer']

# %%
# Generating a txt file for all the job ads description token
finalTokens = getAllDescList(finalJobAds)
finalTokens[1:3]
# Out:
# desList: getAllDescList
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [['timeout',
#   'children',
#   'homes',
#   'rapidly',
#   'expanding',
#   'forefront',
#   'therapeutic',
#   'care',
#   'young',
#   'people',
#   'aged',
#   'years',
#   'emotional',
#   'behavioural',
#   'difficulties',
#   'lives',
#   'recruit',
#   'residential',
#   'care',
#   'workers',
#   'homes',
#   'swindon',
#   'area',
#   'collaboratively',
#   'cooperatively',
#   'timeout',
#   'staff',
#   'young',
#   'people',
#   'external',
#   'agencies',
#   'consultation',
#   'families',
#   'social',
#   'workers',
#   'yot',
#   'professionals',
#   'involved',
#   'young',
#   'person',
#   'education',
#   'deliver',
#   'effective',
#   'educational',
#   'programmes',
#   'applicants',
#   'enhanced',
#   'disclosure',
#   'disclosure',
#   'expense',
#   'met',
#   'employer',
#   'click',
#   'button',
#   'redirected',
#   'site',
#   'complete',
#   'application',
#   'form'],
#  ['french',
#   'restaurant',
#   'club',
#   'gascon',
#   'michelin',
#   'established',
#   'heart',
#   'london',
#   'easy',
#   'access',
#   'bus',
#   'train',
#   'tube',
#   'chef',
#   'de',
#   'rang',
#   'waiter',
#   'complete',
#   'split',
#   'straight',
#   'shifts',
#   'depending',
#   'rota',
#   'days',
#   'week',
#   'closed',
#   'sunday',
#   'bank',
#   'holiday',
#   'average',
#   'week',
#   'real',
#   'career',
#   'progression',
#   'part',
#   'small',
#   'group',
#   'quality',
#   'restaurant',
#   'london',
#   'wages',
#   'basic',
#   'share',
#   'gratuities',
#   'staff',
#   'discount',
#   'restaurants',
#   'check',
#   'site',
#   'clubgascon',
#   'interested',
#   'joining',
#   'send',
#   'detailed',
#   'applied',
#   'arrange',
#   'meeting',
#   'order',
#   'discuss',
#   'offer']]

# %% [markdown]
# ### 8. Extract the top 10 Bigrams(TERM FREQUENCY)

# %%
#  dunction to get bigrams from the list
def extractBigram(blist):
  #  initialise list
  tokenList = list()

  # looping through all the lines of list
  for match in blist:
    # condiiton to check if index 0 of the line starts with "Description"
    if match.find("Description") == 0:
      # tokenize each description string
      tokens = tokenizeDescription(match)
      tokens.remove('Description')

      # extend the tokens to the list
      tokenList.extend(tokens)
  
  # getting ngrams out ot the total tokens
  bigrams = ngrams(tokenList, n = 2)

  # calculating the frequency distribution of bigrams
  fdbigram = FreqDist(bigrams)

  # fetching the top 10 most common bigrams
  bigrams = fdbigram.most_common(10) 

  return bigrams

# %%
#  run function to get bigrams
bigram_found = extractBigram(ListWithoutTop50Words)
bigram_found
# Out:
# [(('employment', 'agency'), 8055),
#  (('track', 'record'), 5472),
#  (('acting', 'employment'), 5095),
#  (('sql', 'server'), 4804),
#  (('asp', 'net'), 4687),
#  (('relation', 'vacancy'), 3977),
#  (('sales', 'executive'), 3619),
#  (('chef', 'de'), 3586),
#  (('nursing', 'home'), 3503),
#  (('de', 'partie'), 3396)]

# %% [markdown]
# ### Vocabulary

# %%
# run function to get all description token list
vocab_list = getAllDescList(finalJobAds)

# put all tokens from the above corpus to a single list
words = list(chain.from_iterable(vocab_list))

# sorted vocabulary by converting the list of tokens to a set
vocab = sorted(list(set(words)))

len(vocab)
# Out:
# 40038

# %% [markdown]
# ## Saving required outputs
# Save the vocabulary, bigrams and job advertisment txt as per spectification.
# - vocab.txt
# - bigram.txt
# - job_ads.txt

# %%
# save vocab with required format
def save_vocab(path, vocab):
  # creates a txt file and open to save the description tokens
  out_file = open(path, "w")
  for word in vocab:
    out_file.write(word + ":" + str(vocab.index(word)) + "\n")
  out_file.close()

# save vocab with only words
def save_vocab_only_words(path, vocab):
  # creates a txt file and open to save the description tokens
  out_file = open(path, 'w')
  string = "\n".join(["".join(v) for v in vocab])
  out_file.write(string)
  out_file.close()

# save bigram with required format
def save_bigram(path, bigrams):
  out_file = open(path, "w")
  for bg in bigrams:
    out_file.write(" ".join(bg[0]) + "," + str(bg[1]) + "\n")
  out_file.close()

# save jobAds with required format
def save_jobAds(path, finalJobAds):
    out_file = open(path, 'w') # creates a txt file and open to save the reviews
    string = "\n".join(["".join(j) for j in finalJobAds])
    out_file.write(string)
    out_file.close()

# save all jobAds token
def save_tokensJobAd(path, finalTokens):
  out_file = open(path, 'w') # creates a txt file and open to save the reviews
  string = "\n".join([" ".join(v) for v in finalTokens])
  out_file.write(string)
  out_file.close()

# %%
save_jobAds("/content/drive/My Drive/Task-2-and-3/job_ads.txt",finalJobAds)

# %%
save_vocab("/content/drive/My Drive/Task-2-and-3/vocab.txt",vocab)

# %%
save_vocab_only_words("/content/drive/My Drive/Task-2-and-3/words-desc-vocab.txt", vocab)

# %%
save_bigram("/content/drive/My Drive/Task-2-and-3/bigram.txt",bigrams)

# %%
save_tokensJobAd("/content/drive/My Drive/Task-2-and-3/tokens_job_ads.txt", finalTokens)

# %% [markdown]
# ## Summary
# All the preprocessing steps were successfully performed on the job advertisement including tokenisation, removing stopwords, words shoter than 2 character length, words that appear only once , top 50 words to make it clean.
